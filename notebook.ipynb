# %%
import pandas as pd

# %%
df = pd.DataFrame(columns=['create', 'deliver', 'destory', 'material'])
df
# Out:
# Empty DataFrame
# Columns: [create, deliver, destory, material]
# Index: []

# %%
'{aa:03d}'.format(aa=3)
# Out:
# '003'

# %%
class IssueRecorder():
    def __init__(self):
        self.prefix = 'Z-L19'
        self.df = pd.DataFrame(columns=['create', 'deliver', 'destory', 'material'])
    
    def append(self, date, idxs, opt, opt_date, material='paper'):
        if type(idxs) is int:
            idxs = [idxs]
        for idx in idxs:
            name = '{prefix}-{date}-{idx:03d}'.format(prefix=self.prefix, date=date, idx=idx)
            print(name)
            se = pd.Series(name=name, data={opt: opt_date, 'material': material})
            print(se)
            self.df = self.df.append(se)
            
    def check(self):
        self.bugs = []
        for name in self.df.index.unique():
            ses = ir.df.loc[name]
            print(ses)
            if len(ses) == 2:
                print('Pass.')
            else:
                print('Bug.')
                self.bugs.append(name)
                
    def report_bugs(self):
        print('=' * 80)
        print('Bugs report.')
        for name in self.bugs:
            print('-' * 80)
            print(ir.df.loc[name])

# %%
ir = IssueRecorder()
ir.df
# Out:
# Empty DataFrame
# Columns: [create, deliver, destory, material]
# Index: []

# %%
ir.check()
# Out:
#                       create   deliver destory material
# Z-L19-20181229-001  20181229       NaN     NaN    paper
# Z-L19-20181229-001       NaN  20190612     NaN    paper
# Pass.
#                       create   deliver destory material
# Z-L19-20181229-002  20181229       NaN     NaN    paper
# Z-L19-20181229-002       NaN  20190612     NaN    paper
# Pass.
#                       create   deliver destory material
# Z-L19-20181229-003  20181229       NaN     NaN    paper
# Z-L19-20181229-003       NaN  20190612     NaN    paper
# Pass.
#                       create   deliver destory material
# Z-L19-20181229-004  20181229       NaN     NaN    paper
# Z-L19-20181229-004       NaN  20190612     NaN    paper
# Pass.
#                       create   deliver destory material
# Z-L19-20181229-005  20181229       NaN     NaN    paper
# Z-L19-20181229-005       NaN  20190612     NaN    paper
# Pass.
#                       create   deliver destory material
# Z-L19-20181229-006  20181229       NaN     NaN    paper
# Z-L19-20181229-006       NaN  20190612     NaN    paper
# Pass.
#                       create   deliver destory material
# Z-L19-20181229-007  20181229       NaN     NaN    paper
# Z-L19-20181229-007       NaN  20190612     NaN    paper
# Pass.
#                       create   deliver destory material
# Z-L19-20181229-008  20181229       NaN     NaN    paper
# Z-L19-20181229-008       NaN  20190612     NaN    paper
# Pass.
#                       create   deliver   destory material
# Z-L19-20181229-009  20181229       NaN       NaN    paper
# Z-L19-20181229-009       NaN  20190612       NaN    paper
# Z-L19-20181229-009       NaN       NaN  20190130    paper
# Bug.
#                       create   deliver   destory material
# Z-L19-20181229-010  20181229       NaN       NaN    paper
# Z-L19-20181229-010       NaN  20190612       NaN    paper
# Z-L19-20181229-010       NaN       NaN  20190130    paper
# Bug.
#                       create deliver   destory material
# Z-L19-20181229-011  20181229     NaN       NaN    plant
# Z-L19-20181229-011       NaN     NaN  20190130    paper
# Pass.
#                       create   deliver   destory material
# Z-L19-20181229-012  20181229       NaN       NaN    plant
# Z-L19-20181229-012       NaN  20190612       NaN    paper
# Z-L19-20181229-012       NaN       NaN  20190130    paper
# Bug.
#                       create deliver   destory material
# Z-L19-20181229-013  20181229     NaN       NaN    paper
# Z-L19-20181229-013       NaN     NaN  20190130    paper
# Pass.
#                       create deliver   destory material
# Z-L19-20190102-001  20190102     NaN       NaN    paper
# Z-L19-20190102-001       NaN     NaN  20190130    paper
# Pass.
#                       create deliver   destory material
# Z-L19-20190102-002  20190102     NaN       NaN    paper
# Z-L19-20190102-002       NaN     NaN  20190130    paper
# Pass.
#                       create deliver   destory material
# Z-L19-20190102-003  20190102     NaN       NaN    paper
# Z-L19-20190102-003       NaN     NaN  20190130    paper
# Pass.
#                       create deliver   destory material
# Z-L19-20190102-004  20190102     NaN       NaN    paper
# Z-L19-20190102-004       NaN     NaN  20190130    paper
# Pass.
#                       create deliver   destory material
# Z-L19-20190102-005  20190102     NaN       NaN    paper
# Z-L19-20190102-005       NaN     NaN  20190130    paper
# Pass.
#                       create deliver   destory material
# Z-L19-20190102-006  20190102     NaN       NaN    paper
# Z-L19-20190102-006       NaN     NaN  20190130    paper
# Pass.
#                       create deliver   destory material
# Z-L19-20190102-007  20190102     NaN       NaN    paper
# Z-L19-20190102-007       NaN     NaN  20190130    paper
# Pass.
#                       create deliver   destory material
# Z-L19-20190102-008  20190102     NaN       NaN    paper
# Z-L19-20190102-008       NaN     NaN  20190130    paper
# Pass.
#                       create deliver   destory material
# Z-L19-20190102-009  20190102     NaN       NaN    plant
# Z-L19-20190102-009       NaN     NaN  20190130    paper
# Pass.
#                       create   deliver destory material
# Z-L19-20190103-001  20190103       NaN     NaN    paper
# Z-L19-20190103-001       NaN  20190612     NaN    paper
# Pass.
#                       create   deliver destory material
# Z-L19-20190103-002  20190103       NaN     NaN    paper
# Z-L19-20190103-002       NaN  20190612     NaN    paper
# Pass.
#                       create   deliver destory material
# Z-L19-20190103-003  20190103       NaN     NaN    plant
# Z-L19-20190103-003       NaN  20190612     NaN    paper
# Pass.
#                       create   deliver destory material
# Z-L19-20190319-001  20190319       NaN     NaN    paper
# Z-L19-20190319-001       NaN  20190320     NaN    paper
# Pass.
#                       create   deliver destory material
# Z-L19-20190319-002  20190319       NaN     NaN    paper
# Z-L19-20190319-002       NaN  20190320     NaN    paper
# Pass.
#                       create   deliver destory material
# Z-L19-20190319-003  20190319       NaN     NaN    paper
# Z-L19-20190319-003       NaN  20190320     NaN    paper
# Pass.
#                       create   deliver destory material
# Z-L19-20190319-004  20190319       NaN     NaN    paper
# Z-L19-20190319-004       NaN  20190320     NaN    paper
# Pass.
#                       create   deliver   destory material
# Z-L19-20190319-005  20190319       NaN       NaN    plant
# Z-L19-20190319-005       NaN  20190320       NaN    paper
# Z-L19-20190319-005       NaN       NaN  20190424    paper
# Bug.
#                       create   deliver destory material
# Z-L19-20190319-006  20190319       NaN     NaN    paper
# Z-L19-20190319-006       NaN  20190320     NaN    paper
# Pass.
#                       create deliver   destory material
# Z-L19-20191025-047  20191025     NaN       NaN    paper
# Z-L19-20191025-047       NaN     NaN  20191025    paper
# Pass.
#                       create deliver   destory material
# Z-L19-20191025-048  20191025     NaN       NaN    paper
# Z-L19-20191025-048       NaN     NaN  20191025    paper
# Pass.
#                       create   deliver destory material
# Z-L19-20191025-049  20191025       NaN     NaN    paper
# Z-L19-20191025-049       NaN  20191026     NaN    paper
# Pass.
#                       create   deliver destory material
# Z-L19-20191025-050  20191025       NaN     NaN    paper
# Z-L19-20191025-050       NaN  20191026     NaN    paper
# Pass.
#                       create   deliver destory material
# Z-L19-20191025-051  20191025       NaN     NaN    paper
# Z-L19-20191025-051       NaN  20191026     NaN    paper
# Pass.
#                       create   deliver destory material
# Z-L19-20191025-052  20191025       NaN     NaN    paper
# Z-L19-20191025-052       NaN  20191026     NaN    paper
# Pass.
#                       create   deliver destory material
# Z-L19-20191025-053  20191025       NaN     NaN    paper
# Z-L19-20191025-053       NaN  20191026     NaN    paper
# Pass.
#                       create   deliver destory material
# Z-L19-20191025-054  20191025       NaN     NaN    paper
# Z-L19-20191025-054       NaN  20191026     NaN    paper
# Pass.
#                       create   deliver destory material
# Z-L19-20191025-055  20191025       NaN     NaN    paper
# Z-L19-20191025-055       NaN  20191026     NaN    paper
# Pass.
#                       create   deliver destory material
# Z-L19-20191025-056  20191025       NaN     NaN    paper
# Z-L19-20191025-056       NaN  20191026     NaN    paper
# Pass.
#                       create   deliver destory material
# Z-L19-20191104-001  20191104       NaN     NaN    paper
# Z-L19-20191104-001       NaN  20191104     NaN    paper
# Pass.
#                       create   deliver destory material
# Z-L19-20191104-002  20191104       NaN     NaN    paper
# Z-L19-20191104-002       NaN  20191104     NaN    paper
# Pass.
#                       create   deliver destory material
# Z-L19-20191104-003  20191104       NaN     NaN    paper
# Z-L19-20191104-003       NaN  20191104     NaN    paper
# Pass.
#                       create   deliver destory material
# Z-L19-20191104-004  20191104       NaN     NaN    paper
# Z-L19-20191104-004       NaN  20191104     NaN    paper
# Pass.
#                       create   deliver destory material
# Z-L19-20191104-005  20191104       NaN     NaN    paper
# Z-L19-20191104-005       NaN  20191104     NaN    paper
# Pass.
#                       create   deliver destory material
# Z-L19-20191104-006  20191104       NaN     NaN    paper
# Z-L19-20191104-006       NaN  20191104     NaN    paper
# Pass.
#                       create   deliver destory material
# Z-L19-20191104-007  20191104       NaN     NaN    paper
# Z-L19-20191104-007       NaN  20191104     NaN    paper
# Pass.
#                       create   deliver destory material
# Z-L19-20191129-002  20191129       NaN     NaN    paper
# Z-L19-20191129-002       NaN  20191129     NaN    paper
# Pass.
#                       create   deliver destory material
# Z-L19-20191129-003  20191129       NaN     NaN    paper
# Z-L19-20191129-003       NaN  20191129     NaN    paper
# Pass.
#                       create   deliver destory material
# Z-L19-20191129-004  20191129       NaN     NaN    paper
# Z-L19-20191129-004       NaN  20191129     NaN    paper
# Pass.
#                       create   deliver destory material
# Z-L19-20191129-005  20191129       NaN     NaN    paper
# Z-L19-20191129-005       NaN  20191129     NaN    paper
# Pass.
#                       create   deliver destory material
# Z-L19-20191129-006  20191129       NaN     NaN    paper
# Z-L19-20191129-006       NaN  20191129     NaN    paper
# Pass.
#                       create   deliver destory material
# Z-L19-20191129-007  20191129       NaN     NaN    paper
# Z-L19-20191129-007       NaN  20191129     NaN    paper
# Pass.
#                       create   deliver destory material
# Z-L19-20191129-008  20191129       NaN     NaN    paper
# Z-L19-20191129-008       NaN  20191129     NaN    paper
# Pass.
#                       create   deliver destory material
# Z-L19-20191129-009  20191129       NaN     NaN    paper
# Z-L19-20191129-009       NaN  20191129     NaN    paper
# Pass.
#                       create   deliver destory material
# Z-L19-20191129-010  20191129       NaN     NaN    paper
# Z-L19-20191129-010       NaN  20191129     NaN    paper
# Pass.
#                       create   deliver destory material
# Z-L19-20191129-011  20191129       NaN     NaN    paper
# Z-L19-20191129-011       NaN  20191129     NaN    paper
# Pass.
#                       create   deliver destory material
# Z-L19-20191129-012  20191129       NaN     NaN    paper
# Z-L19-20191129-012       NaN  20191129     NaN    paper
# Pass.
#                       create   deliver destory material
# Z-L19-20191129-013  20191129       NaN     NaN    paper
# Z-L19-20191129-013       NaN  20191129     NaN    paper
# Pass.
#                       create   deliver destory material
# Z-L19-20191129-014  20191129       NaN     NaN    paper
# Z-L19-20191129-014       NaN  20191129     NaN    paper
# Pass.
#                       create   deliver destory material
# Z-L19-20191129-015  20191129       NaN     NaN    paper
# Z-L19-20191129-015       NaN  20191129     NaN    paper
# Pass.
#                       create   deliver destory material
# Z-L19-20191129-016  20191129       NaN     NaN    paper
# Z-L19-20191129-016       NaN  20191129     NaN    paper
# Pass.
#                       create   deliver destory material
# Z-L19-20191129-017  20191129       NaN     NaN    paper
# Z-L19-20191129-017       NaN  20191129     NaN    paper
# Pass.
#                       create deliver   destory material
# Z-L19-20191129-018  20191129     NaN       NaN    paper
# Z-L19-20191129-018       NaN     NaN  20191129    paper
# Pass.
#                       create deliver   destory material
# Z-L19-20191129-019  20191129     NaN       NaN    paper
# Z-L19-20191129-019       NaN     NaN  20191129    paper
# Pass.
#                       create deliver   destory material
# Z-L19-20191129-020  20191129     NaN       NaN    paper
# Z-L19-20191129-020       NaN     NaN  20191129    paper
# Pass.
#                       create deliver   destory material
# Z-L19-20191129-021  20191129     NaN       NaN    paper
# Z-L19-20191129-021       NaN     NaN  20191129    paper
# Pass.
#                       create deliver   destory material
# Z-L19-20191129-022  20191129     NaN       NaN    paper
# Z-L19-20191129-022       NaN     NaN  20191129    paper
# Pass.
#                       create deliver   destory material
# Z-L19-20191129-023  20191129     NaN       NaN    paper
# Z-L19-20191129-023       NaN     NaN  20191129    paper
# Pass.
#                       create deliver   destory material
# Z-L19-20191129-024  20191129     NaN       NaN    paper
# Z-L19-20191129-024       NaN     NaN  20191129    paper
# Pass.
#                       create deliver   destory material
# Z-L19-20191129-025  20191129     NaN       NaN    paper
# Z-L19-20191129-025       NaN     NaN  20191129    paper
# Pass.
#                       create deliver   destory material
# Z-L19-20191129-026  20191129     NaN       NaN    paper
# Z-L19-20191129-026       NaN     NaN  20191129    paper
# Pass.
#                       create deliver   destory material
# Z-L19-20191129-027  20191129     NaN       NaN    paper
# Z-L19-20191129-027       NaN     NaN  20191129    paper
# Pass.
#                       create deliver   destory material
# Z-L19-20191129-028  20191129     NaN       NaN    paper
# Z-L19-20191129-028       NaN     NaN  20191129    paper
# Pass.
#                       create deliver   destory material
# Z-L19-20191129-029  20191129     NaN       NaN    paper
# Z-L19-20191129-029       NaN     NaN  20191129    paper
# Pass.
#                       create deliver   destory material
# Z-L19-20191129-030  20191129     NaN       NaN    paper
# Z-L19-20191129-030       NaN     NaN  20191129    paper
# Pass.
#                       create deliver   destory material
# Z-L19-20191129-031  20191129     NaN       NaN    paper
# Z-L19-20191129-031       NaN     NaN  20191129    paper
# Pass.
#                       create deliver   destory material
# Z-L19-20191129-032  20191129     NaN       NaN    paper
# Z-L19-20191129-032       NaN     NaN  20191129    paper
# Pass.
#                       create   deliver destory material
# Z-L19-20191206-002  20191206       NaN     NaN    paper
# Z-L19-20191206-002       NaN  20191209     NaN    paper
# Pass.
#                       create   deliver destory material
# Z-L19-20191206-003  20191206       NaN     NaN    paper
# Z-L19-20191206-003       NaN  20191209     NaN    paper
# Pass.
#                       create   deliver destory material
# Z-L19-20191206-004  20191206       NaN     NaN    paper
# Z-L19-20191206-004       NaN  20191209     NaN    paper
# Pass.

# %%
ir.report_bugs()
# Out:
# ================================================================================
# Bugs report.
# --------------------------------------------------------------------------------
#                       create   deliver   destory material
# Z-L19-20181229-009  20181229       NaN       NaN    paper
# Z-L19-20181229-009       NaN  20190612       NaN    paper
# Z-L19-20181229-009       NaN       NaN  20190130    paper
# --------------------------------------------------------------------------------
#                       create   deliver   destory material
# Z-L19-20181229-010  20181229       NaN       NaN    paper
# Z-L19-20181229-010       NaN  20190612       NaN    paper
# Z-L19-20181229-010       NaN       NaN  20190130    paper
# --------------------------------------------------------------------------------
#                       create   deliver   destory material
# Z-L19-20181229-012  20181229       NaN       NaN    plant
# Z-L19-20181229-012       NaN  20190612       NaN    paper
# Z-L19-20181229-012       NaN       NaN  20190130    paper
# --------------------------------------------------------------------------------
#                       create   deliver   destory material
# Z-L19-20190319-005  20190319       NaN       NaN    plant
# Z-L19-20190319-005       NaN  20190320       NaN    paper
# Z-L19-20190319-005       NaN       NaN  20190424    paper

# %%
####################################################
opt = 'create'

date = '20181229'
[ir.append(date, idxs, opt, date, driver)
 for idxs, driver in [[range(1, 7), 'paper'],
                      [range(7, 9), 'paper'],
                      [range(9, 11), 'paper'],
                      [range(11, 13), 'plant'],
                      [13, 'paper']]]

date = '20190102'
[ir.append(date, idxs, opt, date, driver)
 for idxs, driver in [[range(1, 7), 'paper'],
                      [range(7, 9), 'paper'],
                      [9, 'plant']]]

date = '20190103'
[ir.append(date, idxs, opt, date, driver)
 for idxs, driver in [[range(1, 3), 'paper'],
                      [3, 'plant']]]

date = '20190319'
[ir.append(date, idxs, opt, date, driver)
 for idxs, driver in [[range(1, 5), 'paper'],
                      [5, 'plant'],
                      [6, 'paper']]]

####################################################
opt = 'deliver'

opt_date = '20190612'
[ir.append('20181229', idxs, opt, opt_date)
 for idxs in [range(1, 7),
              range(7, 9),
              range(9, 11),
              12]]

opt_date = '20190320'
[ir.append('20190319', idxs, opt, opt_date)
 for idxs in [range(1, 5),
              5,
              6]]

####################################################
opt = 'destory'

opt_date = '20190424'
[ir.append('20190319', idxs, opt, opt_date)
 for idxs in [5]]

opt_date = '20190130'
[ir.append('20181229', idxs, opt, opt_date)
 for idxs in [range(11, 13),
              13,
              range(9, 11)]]
[ir.append('20190102', idxs, opt, opt_date)
 for idxs in [9,
              range(1, 7),
              range(7, 9)]]

#####################################################
opt = 'create'

opt_date = '20191025'
[ir.append('20191025', idxs, opt, opt_date)
for idxs in range(47, 51)]
[ir.append('20191025', idxs, opt, opt_date)
for idxs in range(51, 57)]

#####################################################
opt = 'destory'

opt_data = '20190125'
[ir.append('20191025', idxs, opt, opt_date)
for idxs in [47, 48]]

#####################################################
opt = 'deliver'

opt_date = '20191026'
[ir.append('20191025', idxs, opt, opt_date)
for idxs in [49, 50]]
[ir.append('20191025', idxs, opt, opt_date)
for idxs in range(51, 57)]

#####################################################
opt = 'create'

opt_date = '20191104'
[ir.append('20191104', idxs, opt, opt_date)
for idxs in [1, 2]]
[ir.append('20191104', idxs, opt, opt_date)
for idxs in range(3, 8)]

#####################################################
opt = 'deliver'

opt_date = '20191104'
[ir.append('20191104', idxs, opt, opt_date)
for idxs in [1, 2]]
[ir.append('20191104', idxs, opt, opt_date)
for idxs in range(3, 8)]

#####################################################
opt = 'deliver'

opt_date = '20190612'
[ir.append('20190103', idxs, opt, opt_date)
for idxs in range(1, 4)]

#####################################################
opt = 'create'

opt_date = '20191129'
[ir.append('20191129', idxs, opt, opt_date)
for idxs in range(2, 6)]
[ir.append('20191129', idxs, opt, opt_date)
for idxs in range(6, 18)]

#####################################################
opt = 'create'

opt_date = '20191129'
[ir.append('20191129', idxs, opt, opt_date)
for idxs in range(18, 22)]
[ir.append('20191129', idxs, opt, opt_date)
for idxs in range(22, 33)]

#####################################################
opt = 'destory'

opt_date = '20191129'
[ir.append('20191129', idxs, opt, opt_date)
for idxs in range(18, 22)]
[ir.append('20191129', idxs, opt, opt_date)
for idxs in range(22, 33)]

#####################################################
# Not done ******************************************
opt = 'deliver'

opt_date = '20191129'
[ir.append('20191129', idxs, opt, opt_date)
for idxs in range(2, 6)]
[ir.append('20191129', idxs, opt, opt_date)
for idxs in range(6, 18)]


#####################################################
opt = 'create'

opt_date = '20191206'
[ir.append('20191206', idxs, opt, opt_date)
for idxs in [2, 3, 4]]

#####################################################
opt = 'deliver'

opt_date = '20191209'
[ir.append('20191206', idxs, opt, opt_date)
for idxs in [2, 3, 4]]

print('done')
# Out:
# Z-L19-20181229-001
# create      20181229
# material       paper
# Name: Z-L19-20181229-001, dtype: object
# Z-L19-20181229-002
# create      20181229
# material       paper
# Name: Z-L19-20181229-002, dtype: object
# Z-L19-20181229-003
# create      20181229
# material       paper
# Name: Z-L19-20181229-003, dtype: object
# Z-L19-20181229-004
# create      20181229
# material       paper
# Name: Z-L19-20181229-004, dtype: object
# Z-L19-20181229-005
# create      20181229
# material       paper
# Name: Z-L19-20181229-005, dtype: object
# Z-L19-20181229-006
# create      20181229
# material       paper
# Name: Z-L19-20181229-006, dtype: object
# Z-L19-20181229-007
# create      20181229
# material       paper
# Name: Z-L19-20181229-007, dtype: object
# Z-L19-20181229-008
# create      20181229
# material       paper
# Name: Z-L19-20181229-008, dtype: object
# Z-L19-20181229-009
# create      20181229
# material       paper
# Name: Z-L19-20181229-009, dtype: object
# Z-L19-20181229-010
# create      20181229
# material       paper
# Name: Z-L19-20181229-010, dtype: object
# Z-L19-20181229-011
# create      20181229
# material       plant
# Name: Z-L19-20181229-011, dtype: object
# Z-L19-20181229-012
# create      20181229
# material       plant
# Name: Z-L19-20181229-012, dtype: object
# Z-L19-20181229-013
# create      20181229
# material       paper
# Name: Z-L19-20181229-013, dtype: object
# Z-L19-20190102-001
# create      20190102
# material       paper
# Name: Z-L19-20190102-001, dtype: object
# Z-L19-20190102-002
# create      20190102
# material       paper
# Name: Z-L19-20190102-002, dtype: object
# Z-L19-20190102-003
# create      20190102
# material       paper
# Name: Z-L19-20190102-003, dtype: object
# Z-L19-20190102-004
# create      20190102
# material       paper
# Name: Z-L19-20190102-004, dtype: object
# Z-L19-20190102-005
# create      20190102
# material       paper
# Name: Z-L19-20190102-005, dtype: object
# Z-L19-20190102-006
# create      20190102
# material       paper
# Name: Z-L19-20190102-006, dtype: object
# Z-L19-20190102-007
# create      20190102
# material       paper
# Name: Z-L19-20190102-007, dtype: object
# Z-L19-20190102-008
# create      20190102
# material       paper
# Name: Z-L19-20190102-008, dtype: object
# Z-L19-20190102-009
# create      20190102
# material       plant
# Name: Z-L19-20190102-009, dtype: object
# Z-L19-20190103-001
# create      20190103
# material       paper
# Name: Z-L19-20190103-001, dtype: object
# Z-L19-20190103-002
# create      20190103
# material       paper
# Name: Z-L19-20190103-002, dtype: object
# Z-L19-20190103-003
# create      20190103
# material       plant
# Name: Z-L19-20190103-003, dtype: object
# Z-L19-20190319-001
# create      20190319
# material       paper
# Name: Z-L19-20190319-001, dtype: object
# Z-L19-20190319-002
# create      20190319
# material       paper
# Name: Z-L19-20190319-002, dtype: object
# Z-L19-20190319-003
# create      20190319
# material       paper
# Name: Z-L19-20190319-003, dtype: object
# Z-L19-20190319-004
# create      20190319
# material       paper
# Name: Z-L19-20190319-004, dtype: object
# Z-L19-20190319-005
# create      20190319
# material       plant
# Name: Z-L19-20190319-005, dtype: object
# Z-L19-20190319-006
# create      20190319
# material       paper
# Name: Z-L19-20190319-006, dtype: object
# Z-L19-20181229-001
# deliver     20190612
# material       paper
# Name: Z-L19-20181229-001, dtype: object
# Z-L19-20181229-002
# deliver     20190612
# material       paper
# Name: Z-L19-20181229-002, dtype: object
# Z-L19-20181229-003
# deliver     20190612
# material       paper
# Name: Z-L19-20181229-003, dtype: object
# Z-L19-20181229-004
# deliver     20190612
# material       paper
# Name: Z-L19-20181229-004, dtype: object
# Z-L19-20181229-005
# deliver     20190612
# material       paper
# Name: Z-L19-20181229-005, dtype: object
# Z-L19-20181229-006
# deliver     20190612
# material       paper
# Name: Z-L19-20181229-006, dtype: object
# Z-L19-20181229-007
# deliver     20190612
# material       paper
# Name: Z-L19-20181229-007, dtype: object
# Z-L19-20181229-008
# deliver     20190612
# material       paper
# Name: Z-L19-20181229-008, dtype: object
# Z-L19-20181229-009
# deliver     20190612
# material       paper
# Name: Z-L19-20181229-009, dtype: object
# Z-L19-20181229-010
# deliver     20190612
# material       paper
# Name: Z-L19-20181229-010, dtype: object
# Z-L19-20181229-012
# deliver     20190612
# material       paper
# Name: Z-L19-20181229-012, dtype: object
# Z-L19-20190319-001
# deliver     20190320
# material       paper
# Name: Z-L19-20190319-001, dtype: object
# Z-L19-20190319-002
# deliver     20190320
# material       paper
# Name: Z-L19-20190319-002, dtype: object
# Z-L19-20190319-003
# deliver     20190320
# material       paper
# Name: Z-L19-20190319-003, dtype: object
# Z-L19-20190319-004
# deliver     20190320
# material       paper
# Name: Z-L19-20190319-004, dtype: object
# Z-L19-20190319-005
# deliver     20190320
# material       paper
# Name: Z-L19-20190319-005, dtype: object
# Z-L19-20190319-006
# deliver     20190320
# material       paper
# Name: Z-L19-20190319-006, dtype: object
# Z-L19-20190319-005
# destory     20190424
# material       paper
# Name: Z-L19-20190319-005, dtype: object
# Z-L19-20181229-011
# destory     20190130
# material       paper
# Name: Z-L19-20181229-011, dtype: object
# Z-L19-20181229-012
# destory     20190130
# material       paper
# Name: Z-L19-20181229-012, dtype: object
# Z-L19-20181229-013
# destory     20190130
# material       paper
# Name: Z-L19-20181229-013, dtype: object
# Z-L19-20181229-009
# destory     20190130
# material       paper
# Name: Z-L19-20181229-009, dtype: object
# Z-L19-20181229-010
# destory     20190130
# material       paper
# Name: Z-L19-20181229-010, dtype: object
# Z-L19-20190102-009
# destory     20190130
# material       paper
# Name: Z-L19-20190102-009, dtype: object
# Z-L19-20190102-001
# destory     20190130
# material       paper
# Name: Z-L19-20190102-001, dtype: object
# Z-L19-20190102-002
# destory     20190130
# material       paper
# Name: Z-L19-20190102-002, dtype: object
# Z-L19-20190102-003
# destory     20190130
# material       paper
# Name: Z-L19-20190102-003, dtype: object
# Z-L19-20190102-004
# destory     20190130
# material       paper
# Name: Z-L19-20190102-004, dtype: object
# Z-L19-20190102-005
# destory     20190130
# material       paper
# Name: Z-L19-20190102-005, dtype: object
# Z-L19-20190102-006
# destory     20190130
# material       paper
# Name: Z-L19-20190102-006, dtype: object
# Z-L19-20190102-007
# destory     20190130
# material       paper
# Name: Z-L19-20190102-007, dtype: object
# Z-L19-20190102-008
# destory     20190130
# material       paper
# Name: Z-L19-20190102-008, dtype: object
# Z-L19-20191025-047
# create      20191025
# material       paper
# Name: Z-L19-20191025-047, dtype: object
# Z-L19-20191025-048
# create      20191025
# material       paper
# Name: Z-L19-20191025-048, dtype: object
# Z-L19-20191025-049
# create      20191025
# material       paper
# Name: Z-L19-20191025-049, dtype: object
# Z-L19-20191025-050
# create      20191025
# material       paper
# Name: Z-L19-20191025-050, dtype: object
# Z-L19-20191025-051
# create      20191025
# material       paper
# Name: Z-L19-20191025-051, dtype: object
# Z-L19-20191025-052
# create      20191025
# material       paper
# Name: Z-L19-20191025-052, dtype: object
# Z-L19-20191025-053
# create      20191025
# material       paper
# Name: Z-L19-20191025-053, dtype: object
# Z-L19-20191025-054
# create      20191025
# material       paper
# Name: Z-L19-20191025-054, dtype: object
# Z-L19-20191025-055
# create      20191025
# material       paper
# Name: Z-L19-20191025-055, dtype: object
# Z-L19-20191025-056
# create      20191025
# material       paper
# Name: Z-L19-20191025-056, dtype: object
# Z-L19-20191025-047
# destory     20191025
# material       paper
# Name: Z-L19-20191025-047, dtype: object
# Z-L19-20191025-048
# destory     20191025
# material       paper
# Name: Z-L19-20191025-048, dtype: object
# Z-L19-20191025-049
# deliver     20191026
# material       paper
# Name: Z-L19-20191025-049, dtype: object
# Z-L19-20191025-050
# deliver     20191026
# material       paper
# Name: Z-L19-20191025-050, dtype: object
# Z-L19-20191025-051
# deliver     20191026
# material       paper
# Name: Z-L19-20191025-051, dtype: object
# Z-L19-20191025-052
# deliver     20191026
# material       paper
# Name: Z-L19-20191025-052, dtype: object
# Z-L19-20191025-053
# deliver     20191026
# material       paper
# Name: Z-L19-20191025-053, dtype: object
# Z-L19-20191025-054
# deliver     20191026
# material       paper
# Name: Z-L19-20191025-054, dtype: object
# Z-L19-20191025-055
# deliver     20191026
# material       paper
# Name: Z-L19-20191025-055, dtype: object
# Z-L19-20191025-056
# deliver     20191026
# material       paper
# Name: Z-L19-20191025-056, dtype: object
# Z-L19-20191104-001
# create      20191104
# material       paper
# Name: Z-L19-20191104-001, dtype: object
# Z-L19-20191104-002
# create      20191104
# material       paper
# Name: Z-L19-20191104-002, dtype: object
# Z-L19-20191104-003
# create      20191104
# material       paper
# Name: Z-L19-20191104-003, dtype: object
# Z-L19-20191104-004
# create      20191104
# material       paper
# Name: Z-L19-20191104-004, dtype: object
# Z-L19-20191104-005
# create      20191104
# material       paper
# Name: Z-L19-20191104-005, dtype: object
# Z-L19-20191104-006
# create      20191104
# material       paper
# Name: Z-L19-20191104-006, dtype: object
# Z-L19-20191104-007
# create      20191104
# material       paper
# Name: Z-L19-20191104-007, dtype: object
# Z-L19-20191104-001
# deliver     20191104
# material       paper
# Name: Z-L19-20191104-001, dtype: object
# Z-L19-20191104-002
# deliver     20191104
# material       paper
# Name: Z-L19-20191104-002, dtype: object
# Z-L19-20191104-003
# deliver     20191104
# material       paper
# Name: Z-L19-20191104-003, dtype: object
# Z-L19-20191104-004
# deliver     20191104
# material       paper
# Name: Z-L19-20191104-004, dtype: object
# Z-L19-20191104-005
# deliver     20191104
# material       paper
# Name: Z-L19-20191104-005, dtype: object
# Z-L19-20191104-006
# deliver     20191104
# material       paper
# Name: Z-L19-20191104-006, dtype: object
# Z-L19-20191104-007
# deliver     20191104
# material       paper
# Name: Z-L19-20191104-007, dtype: object
# Z-L19-20190103-001
# deliver     20190612
# material       paper
# Name: Z-L19-20190103-001, dtype: object
# Z-L19-20190103-002
# deliver     20190612
# material       paper
# Name: Z-L19-20190103-002, dtype: object
# Z-L19-20190103-003
# deliver     20190612
# material       paper
# Name: Z-L19-20190103-003, dtype: object
# Z-L19-20191129-002
# create      20191129
# material       paper
# Name: Z-L19-20191129-002, dtype: object
# Z-L19-20191129-003
# create      20191129
# material       paper
# Name: Z-L19-20191129-003, dtype: object
# Z-L19-20191129-004
# create      20191129
# material       paper
# Name: Z-L19-20191129-004, dtype: object
# Z-L19-20191129-005
# create      20191129
# material       paper
# Name: Z-L19-20191129-005, dtype: object
# Z-L19-20191129-006
# create      20191129
# material       paper
# Name: Z-L19-20191129-006, dtype: object
# Z-L19-20191129-007
# create      20191129
# material       paper
# Name: Z-L19-20191129-007, dtype: object
# Z-L19-20191129-008
# create      20191129
# material       paper
# Name: Z-L19-20191129-008, dtype: object
# Z-L19-20191129-009
# create      20191129
# material       paper
# Name: Z-L19-20191129-009, dtype: object
# Z-L19-20191129-010
# create      20191129
# material       paper
# Name: Z-L19-20191129-010, dtype: object
# Z-L19-20191129-011
# create      20191129
# material       paper
# Name: Z-L19-20191129-011, dtype: object
# Z-L19-20191129-012
# create      20191129
# material       paper
# Name: Z-L19-20191129-012, dtype: object
# Z-L19-20191129-013
# create      20191129
# material       paper
# Name: Z-L19-20191129-013, dtype: object
# Z-L19-20191129-014
# create      20191129
# material       paper
# Name: Z-L19-20191129-014, dtype: object
# Z-L19-20191129-015
# create      20191129
# material       paper
# Name: Z-L19-20191129-015, dtype: object
# Z-L19-20191129-016
# create      20191129
# material       paper
# Name: Z-L19-20191129-016, dtype: object
# Z-L19-20191129-017
# create      20191129
# material       paper
# Name: Z-L19-20191129-017, dtype: object
# Z-L19-20191129-018
# create      20191129
# material       paper
# Name: Z-L19-20191129-018, dtype: object
# Z-L19-20191129-019
# create      20191129
# material       paper
# Name: Z-L19-20191129-019, dtype: object
# Z-L19-20191129-020
# create      20191129
# material       paper
# Name: Z-L19-20191129-020, dtype: object
# Z-L19-20191129-021
# create      20191129
# material       paper
# Name: Z-L19-20191129-021, dtype: object
# Z-L19-20191129-022
# create      20191129
# material       paper
# Name: Z-L19-20191129-022, dtype: object
# Z-L19-20191129-023
# create      20191129
# material       paper
# Name: Z-L19-20191129-023, dtype: object
# Z-L19-20191129-024
# create      20191129
# material       paper
# Name: Z-L19-20191129-024, dtype: object
# Z-L19-20191129-025
# create      20191129
# material       paper
# Name: Z-L19-20191129-025, dtype: object
# Z-L19-20191129-026
# create      20191129
# material       paper
# Name: Z-L19-20191129-026, dtype: object
# Z-L19-20191129-027
# create      20191129
# material       paper
# Name: Z-L19-20191129-027, dtype: object
# Z-L19-20191129-028
# create      20191129
# material       paper
# Name: Z-L19-20191129-028, dtype: object
# Z-L19-20191129-029
# create      20191129
# material       paper
# Name: Z-L19-20191129-029, dtype: object
# Z-L19-20191129-030
# create      20191129
# material       paper
# Name: Z-L19-20191129-030, dtype: object
# Z-L19-20191129-031
# create      20191129
# material       paper
# Name: Z-L19-20191129-031, dtype: object
# Z-L19-20191129-032
# create      20191129
# material       paper
# Name: Z-L19-20191129-032, dtype: object
# Z-L19-20191129-018
# destory     20191129
# material       paper
# Name: Z-L19-20191129-018, dtype: object
# Z-L19-20191129-019
# destory     20191129
# material       paper
# Name: Z-L19-20191129-019, dtype: object
# Z-L19-20191129-020
# destory     20191129
# material       paper
# Name: Z-L19-20191129-020, dtype: object
# Z-L19-20191129-021
# destory     20191129
# material       paper
# Name: Z-L19-20191129-021, dtype: object
# Z-L19-20191129-022
# destory     20191129
# material       paper
# Name: Z-L19-20191129-022, dtype: object
# Z-L19-20191129-023
# destory     20191129
# material       paper
# Name: Z-L19-20191129-023, dtype: object
# Z-L19-20191129-024
# destory     20191129
# material       paper
# Name: Z-L19-20191129-024, dtype: object
# Z-L19-20191129-025
# destory     20191129
# material       paper
# Name: Z-L19-20191129-025, dtype: object
# Z-L19-20191129-026
# destory     20191129
# material       paper
# Name: Z-L19-20191129-026, dtype: object
# Z-L19-20191129-027
# destory     20191129
# material       paper
# Name: Z-L19-20191129-027, dtype: object
# Z-L19-20191129-028
# destory     20191129
# material       paper
# Name: Z-L19-20191129-028, dtype: object
# Z-L19-20191129-029
# destory     20191129
# material       paper
# Name: Z-L19-20191129-029, dtype: object
# Z-L19-20191129-030
# destory     20191129
# material       paper
# Name: Z-L19-20191129-030, dtype: object
# Z-L19-20191129-031
# destory     20191129
# material       paper
# Name: Z-L19-20191129-031, dtype: object
# Z-L19-20191129-032
# destory     20191129
# material       paper
# Name: Z-L19-20191129-032, dtype: object
# Z-L19-20191129-002
# deliver     20191129
# material       paper
# Name: Z-L19-20191129-002, dtype: object
# Z-L19-20191129-003
# deliver     20191129
# material       paper
# Name: Z-L19-20191129-003, dtype: object
# Z-L19-20191129-004
# deliver     20191129
# material       paper
# Name: Z-L19-20191129-004, dtype: object
# Z-L19-20191129-005
# deliver     20191129
# material       paper
# Name: Z-L19-20191129-005, dtype: object
# Z-L19-20191129-006
# deliver     20191129
# material       paper
# Name: Z-L19-20191129-006, dtype: object
# Z-L19-20191129-007
# deliver     20191129
# material       paper
# Name: Z-L19-20191129-007, dtype: object
# Z-L19-20191129-008
# deliver     20191129
# material       paper
# Name: Z-L19-20191129-008, dtype: object
# Z-L19-20191129-009
# deliver     20191129
# material       paper
# Name: Z-L19-20191129-009, dtype: object
# Z-L19-20191129-010
# deliver     20191129
# material       paper
# Name: Z-L19-20191129-010, dtype: object
# Z-L19-20191129-011
# deliver     20191129
# material       paper
# Name: Z-L19-20191129-011, dtype: object
# Z-L19-20191129-012
# deliver     20191129
# material       paper
# Name: Z-L19-20191129-012, dtype: object
# Z-L19-20191129-013
# deliver     20191129
# material       paper
# Name: Z-L19-20191129-013, dtype: object
# Z-L19-20191129-014
# deliver     20191129
# material       paper
# Name: Z-L19-20191129-014, dtype: object
# Z-L19-20191129-015
# deliver     20191129
# material       paper
# Name: Z-L19-20191129-015, dtype: object
# Z-L19-20191129-016
# deliver     20191129
# material       paper
# Name: Z-L19-20191129-016, dtype: object
# Z-L19-20191129-017
# deliver     20191129
# material       paper
# Name: Z-L19-20191129-017, dtype: object
# Z-L19-20191206-002
# create      20191206
# material       paper
# Name: Z-L19-20191206-002, dtype: object
# Z-L19-20191206-003
# create      20191206
# material       paper
# Name: Z-L19-20191206-003, dtype: object
# Z-L19-20191206-004
# create      20191206
# material       paper
# Name: Z-L19-20191206-004, dtype: object
# Z-L19-20191206-002
# deliver     20191209
# material       paper
# Name: Z-L19-20191206-002, dtype: object
# Z-L19-20191206-003
# deliver     20191209
# material       paper
# Name: Z-L19-20191206-003, dtype: object
# Z-L19-20191206-004
# deliver     20191209
# material       paper
# Name: Z-L19-20191206-004, dtype: object
# done
