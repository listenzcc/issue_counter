# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(columns=['create', 'deliver', 'destory', 'material'])
df
# Out:
# Empty DataFrame
# Columns: [create, deliver, destory, material]
# Index: []

# %%
class IssueRecorder():
    def __init__(self):
        # ID prefix
        self.prefix = 'Z-L19'
        # Main dataframe
        self.df = pd.DataFrame(columns=['create', 'deliver', 'destory', 'material'])
    
    def append(self, date, idxs, opt, opt_date, material='--'):
        # Append new issue
        # date: date of ID
        # idxs: list of ID index
        # opt: operation: create, deliver, destory
        # opt_date: operating date
        
        # idxs should be a list
        if type(idxs) is int:
            idxs = [idxs]
            
        # For each index
        for idx in idxs:
            # Issue name
            name = '{prefix}-{date}-{idx:03d}'.format(prefix=self.prefix, date=date, idx=idx)
            print(name)
            # Build series
            se = pd.Series(name=name, data={opt: opt_date, 'material': material})
            print(se)
            # Append series into main dataframe
            self.df = self.df.append(se)
            
    def check(self):
        # Walk throught main dataframe, and check issues
        self.df = self.df.fillna('--')
        # Init bug list
        self.bugs = []
        self.checked = pd.DataFrame(columns=['create', 'deliver', 'destory'])
        # For each issue name
        for name in self.df.index.unique():
            # There should be several records for certain issue name
            ses = ir.df.loc[name]
            print(ses)
            # If closed well, print pass,
            # if not, print bug and record into bug list
            if self.check_finish(ses):  # len(ses) == 2:
                print('Pass.')
            else:
                print('Bug.')
                self.bugs.append(name)
    
    def check_finish(self, ses):
        # Check if the session closed
        # ses: a series of certain issue name
        
        # name: Issue name
        name = ses.index.unique()
        if len(name) > 1:
            return False
        name = name[0]
        
        # A closed session should contain exactly 2 records
        if not len(ses) == 2:
            return False
        
        # a, b: two records
        a = ses.iloc[0].to_dict()
        b = ses.iloc[1].to_dict()
        
        # The issue in a closed session should not be created twice
        if all([a['create'] == '--', b['create'] == '--']):
            return False
        
        # data: data of circle report of the issue
        data = dict(
            create = '--',
            deliver = '--',
            destory = '--',
        )
        # Fill data using a and b
        if a['create'] == '--':
            data['create'] = b['create']
            if a['destory'] == '--':
                data['deliver'] = a['deliver']
            else:
                data['destory'] = a['destory']
        else:
            data['create'] = a['create']
            if b['destory'] == '--':
                data['deliver'] = b['deliver']
            else:
                data['destory'] = b['destory']
        
        # Check if creating date is in front of delivering or destorying.
        d = 'deliver'
        if data['deliver'] == '--':
            d = 'destory'
            if data['create'] > data[d]:
                return False
            
        # The issue is fine, record it into checked
        self.checked = self.checked.append(pd.Series(name=name, data=data))
        return True
    
    def logging(self, message, fp, to_html=False):
        print(message)
        if to_html:
            message = message.to_html()
        print('\n'.join(['<div>', message, '</div>']), file=fp)
    
    def report_bugs(self):
        with open('bugs.html', 'w') as fp:
            self.logging('=' * 80, fp)
            self.logging('Bugs report.', fp)
            for name in self.bugs:
                self.logging('-' * 80, fp)
                self.logging(ir.df.loc[name], fp, to_html=True)

# %%
ir = IssueRecorder()
ir.df
# Out:
# Empty DataFrame
# Columns: [create, deliver, destory, material]
# Index: []

# %%
####################################################
opt = 'create'

date = '20181229'
[ir.append(date, idxs, opt, date, driver)
 for idxs, driver in [[range(1, 7), 'paper'],
                      [range(7, 9), 'paper'],
                      [range(9, 11), 'paper'],
                      [range(11, 13), 'plant'],
                      [13, 'paper']]]

date = '20190102'
[ir.append(date, idxs, opt, date, driver)
 for idxs, driver in [[range(1, 7), 'paper'],
                      [range(7, 9), 'paper'],
                      [9, 'plant']]]

date = '20190103'
[ir.append(date, idxs, opt, date, driver)
 for idxs, driver in [[range(1, 3), 'paper'],
                      [3, 'plant']]]

date = '20190319'
[ir.append(date, idxs, opt, date, driver)
 for idxs, driver in [[range(1, 5), 'paper'],
                      [5, 'plant'],
                      [6, 'paper']]]

####################################################
opt = 'deliver'

opt_date = '20190612'
[ir.append('20181229', idxs, opt, opt_date)
 for idxs in [range(1, 7),
              range(7, 9),
              range(9, 11),
              12]]

opt_date = '20190320'
[ir.append('20190319', idxs, opt, opt_date)
 for idxs in [range(1, 5),
              5,
              6]]

####################################################
opt = 'destory'

opt_date = '20190424'
[ir.append('20190319', idxs, opt, opt_date)
 for idxs in [5]]

opt_date = '20190130'
[ir.append('20181229', idxs, opt, opt_date)
 for idxs in [range(11, 13),
              13,
              range(9, 11)]]
[ir.append('20190102', idxs, opt, opt_date)
 for idxs in [9,
              range(1, 7),
              range(7, 9)]]

#####################################################
opt = 'create'

opt_date = '20191025'
[ir.append('20191025', idxs, opt, opt_date)
for idxs in range(47, 51)]
[ir.append('20191025', idxs, opt, opt_date)
for idxs in range(51, 57)]

#####################################################
opt = 'destory'

opt_data = '20190125'
[ir.append('20191025', idxs, opt, opt_date)
for idxs in [47, 48]]

#####################################################
opt = 'deliver'

opt_date = '20191026'
[ir.append('20191025', idxs, opt, opt_date)
for idxs in [49, 50]]
[ir.append('20191025', idxs, opt, opt_date)
for idxs in range(51, 57)]

#####################################################
opt = 'create'

opt_date = '20191104'
[ir.append('20191104', idxs, opt, opt_date)
for idxs in [1, 2]]
[ir.append('20191104', idxs, opt, opt_date)
for idxs in range(3, 8)]

#####################################################
opt = 'deliver'

opt_date = '20191104'
[ir.append('20191104', idxs, opt, opt_date)
for idxs in [1, 2]]
[ir.append('20191104', idxs, opt, opt_date)
for idxs in range(3, 8)]

#####################################################
opt = 'deliver'

opt_date = '20190612'
[ir.append('20190103', idxs, opt, opt_date)
for idxs in range(1, 4)]

#####################################################
opt = 'create'

opt_date = '20191129'
[ir.append('20191129', idxs, opt, opt_date)
for idxs in range(2, 6)]
[ir.append('20191129', idxs, opt, opt_date)
for idxs in range(6, 18)]

#####################################################
opt = 'create'

opt_date = '20191129'
[ir.append('20191129', idxs, opt, opt_date)
for idxs in range(18, 22)]
[ir.append('20191129', idxs, opt, opt_date)
for idxs in range(22, 33)]

#####################################################
opt = 'destory'

opt_date = '20191129'
[ir.append('20191129', idxs, opt, opt_date)
for idxs in range(18, 22)]
[ir.append('20191129', idxs, opt, opt_date)
for idxs in range(22, 33)]

#####################################################
opt = 'deliver'

opt_date = '20191129'
[ir.append('20191129', idxs, opt, opt_date)
for idxs in range(2, 6)]
[ir.append('20191129', idxs, opt, opt_date)
for idxs in range(6, 18)]

#####################################################
opt = 'create'

opt_date = '20191206'
[ir.append('20191206', idxs, opt, opt_date)
for idxs in [2, 3, 4]]

#####################################################
opt = 'deliver'

opt_date = '20191209'
[ir.append('20191206', idxs, opt, opt_date)
for idxs in [2, 3, 4]]

######################################################
opt = 'create'

opt_date = '20191223'
[ir.append('20191223', idxs, opt, opt_date)
for idxs in [1]]

######################################################
opt = 'deliver'

opt_date = '20191223'
[ir.append('20191223', idxs, opt, opt_date)
for idxs in [1]]

print('done')
# Out:
# Z-L19-20181229-001
# create      20181229
# material       paper
# Name: Z-L19-20181229-001, dtype: object
# Z-L19-20181229-002
# create      20181229
# material       paper
# Name: Z-L19-20181229-002, dtype: object
# Z-L19-20181229-003
# create      20181229
# material       paper
# Name: Z-L19-20181229-003, dtype: object
# Z-L19-20181229-004
# create      20181229
# material       paper
# Name: Z-L19-20181229-004, dtype: object
# Z-L19-20181229-005
# create      20181229
# material       paper
# Name: Z-L19-20181229-005, dtype: object
# Z-L19-20181229-006
# create      20181229
# material       paper
# Name: Z-L19-20181229-006, dtype: object
# Z-L19-20181229-007
# create      20181229
# material       paper
# Name: Z-L19-20181229-007, dtype: object
# Z-L19-20181229-008
# create      20181229
# material       paper
# Name: Z-L19-20181229-008, dtype: object
# Z-L19-20181229-009
# create      20181229
# material       paper
# Name: Z-L19-20181229-009, dtype: object
# Z-L19-20181229-010
# create      20181229
# material       paper
# Name: Z-L19-20181229-010, dtype: object
# Z-L19-20181229-011
# create      20181229
# material       plant
# Name: Z-L19-20181229-011, dtype: object
# Z-L19-20181229-012
# create      20181229
# material       plant
# Name: Z-L19-20181229-012, dtype: object
# Z-L19-20181229-013
# create      20181229
# material       paper
# Name: Z-L19-20181229-013, dtype: object
# Z-L19-20190102-001
# create      20190102
# material       paper
# Name: Z-L19-20190102-001, dtype: object
# Z-L19-20190102-002
# create      20190102
# material       paper
# Name: Z-L19-20190102-002, dtype: object
# Z-L19-20190102-003
# create      20190102
# material       paper
# Name: Z-L19-20190102-003, dtype: object
# Z-L19-20190102-004
# create      20190102
# material       paper
# Name: Z-L19-20190102-004, dtype: object
# Z-L19-20190102-005
# create      20190102
# material       paper
# Name: Z-L19-20190102-005, dtype: object
# Z-L19-20190102-006
# create      20190102
# material       paper
# Name: Z-L19-20190102-006, dtype: object
# Z-L19-20190102-007
# create      20190102
# material       paper
# Name: Z-L19-20190102-007, dtype: object
# Z-L19-20190102-008
# create      20190102
# material       paper
# Name: Z-L19-20190102-008, dtype: object
# Z-L19-20190102-009
# create      20190102
# material       plant
# Name: Z-L19-20190102-009, dtype: object
# Z-L19-20190103-001
# create      20190103
# material       paper
# Name: Z-L19-20190103-001, dtype: object
# Z-L19-20190103-002
# create      20190103
# material       paper
# Name: Z-L19-20190103-002, dtype: object
# Z-L19-20190103-003
# create      20190103
# material       plant
# Name: Z-L19-20190103-003, dtype: object
# Z-L19-20190319-001
# create      20190319
# material       paper
# Name: Z-L19-20190319-001, dtype: object
# Z-L19-20190319-002
# create      20190319
# material       paper
# Name: Z-L19-20190319-002, dtype: object
# Z-L19-20190319-003
# create      20190319
# material       paper
# Name: Z-L19-20190319-003, dtype: object
# Z-L19-20190319-004
# create      20190319
# material       paper
# Name: Z-L19-20190319-004, dtype: object
# Z-L19-20190319-005
# create      20190319
# material       plant
# Name: Z-L19-20190319-005, dtype: object
# Z-L19-20190319-006
# create      20190319
# material       paper
# Name: Z-L19-20190319-006, dtype: object
# Z-L19-20181229-001
# deliver     20190612
# material          --
# Name: Z-L19-20181229-001, dtype: object
# Z-L19-20181229-002
# deliver     20190612
# material          --
# Name: Z-L19-20181229-002, dtype: object
# Z-L19-20181229-003
# deliver     20190612
# material          --
# Name: Z-L19-20181229-003, dtype: object
# Z-L19-20181229-004
# deliver     20190612
# material          --
# Name: Z-L19-20181229-004, dtype: object
# Z-L19-20181229-005
# deliver     20190612
# material          --
# Name: Z-L19-20181229-005, dtype: object
# Z-L19-20181229-006
# deliver     20190612
# material          --
# Name: Z-L19-20181229-006, dtype: object
# Z-L19-20181229-007
# deliver     20190612
# material          --
# Name: Z-L19-20181229-007, dtype: object
# Z-L19-20181229-008
# deliver     20190612
# material          --
# Name: Z-L19-20181229-008, dtype: object
# Z-L19-20181229-009
# deliver     20190612
# material          --
# Name: Z-L19-20181229-009, dtype: object
# Z-L19-20181229-010
# deliver     20190612
# material          --
# Name: Z-L19-20181229-010, dtype: object
# Z-L19-20181229-012
# deliver     20190612
# material          --
# Name: Z-L19-20181229-012, dtype: object
# Z-L19-20190319-001
# deliver     20190320
# material          --
# Name: Z-L19-20190319-001, dtype: object
# Z-L19-20190319-002
# deliver     20190320
# material          --
# Name: Z-L19-20190319-002, dtype: object
# Z-L19-20190319-003
# deliver     20190320
# material          --
# Name: Z-L19-20190319-003, dtype: object
# Z-L19-20190319-004
# deliver     20190320
# material          --
# Name: Z-L19-20190319-004, dtype: object
# Z-L19-20190319-005
# deliver     20190320
# material          --
# Name: Z-L19-20190319-005, dtype: object
# Z-L19-20190319-006
# deliver     20190320
# material          --
# Name: Z-L19-20190319-006, dtype: object
# Z-L19-20190319-005
# destory     20190424
# material          --
# Name: Z-L19-20190319-005, dtype: object
# Z-L19-20181229-011
# destory     20190130
# material          --
# Name: Z-L19-20181229-011, dtype: object
# Z-L19-20181229-012
# destory     20190130
# material          --
# Name: Z-L19-20181229-012, dtype: object
# Z-L19-20181229-013
# destory     20190130
# material          --
# Name: Z-L19-20181229-013, dtype: object
# Z-L19-20181229-009
# destory     20190130
# material          --
# Name: Z-L19-20181229-009, dtype: object
# Z-L19-20181229-010
# destory     20190130
# material          --
# Name: Z-L19-20181229-010, dtype: object
# Z-L19-20190102-009
# destory     20190130
# material          --
# Name: Z-L19-20190102-009, dtype: object
# Z-L19-20190102-001
# destory     20190130
# material          --
# Name: Z-L19-20190102-001, dtype: object
# Z-L19-20190102-002
# destory     20190130
# material          --
# Name: Z-L19-20190102-002, dtype: object
# Z-L19-20190102-003
# destory     20190130
# material          --
# Name: Z-L19-20190102-003, dtype: object
# Z-L19-20190102-004
# destory     20190130
# material          --
# Name: Z-L19-20190102-004, dtype: object
# Z-L19-20190102-005
# destory     20190130
# material          --
# Name: Z-L19-20190102-005, dtype: object
# Z-L19-20190102-006
# destory     20190130
# material          --
# Name: Z-L19-20190102-006, dtype: object
# Z-L19-20190102-007
# destory     20190130
# material          --
# Name: Z-L19-20190102-007, dtype: object
# Z-L19-20190102-008
# destory     20190130
# material          --
# Name: Z-L19-20190102-008, dtype: object
# Z-L19-20191025-047
# create      20191025
# material          --
# Name: Z-L19-20191025-047, dtype: object
# Z-L19-20191025-048
# create      20191025
# material          --
# Name: Z-L19-20191025-048, dtype: object
# Z-L19-20191025-049
# create      20191025
# material          --
# Name: Z-L19-20191025-049, dtype: object
# Z-L19-20191025-050
# create      20191025
# material          --
# Name: Z-L19-20191025-050, dtype: object
# Z-L19-20191025-051
# create      20191025
# material          --
# Name: Z-L19-20191025-051, dtype: object
# Z-L19-20191025-052
# create      20191025
# material          --
# Name: Z-L19-20191025-052, dtype: object
# Z-L19-20191025-053
# create      20191025
# material          --
# Name: Z-L19-20191025-053, dtype: object
# Z-L19-20191025-054
# create      20191025
# material          --
# Name: Z-L19-20191025-054, dtype: object
# Z-L19-20191025-055
# create      20191025
# material          --
# Name: Z-L19-20191025-055, dtype: object
# Z-L19-20191025-056
# create      20191025
# material          --
# Name: Z-L19-20191025-056, dtype: object
# Z-L19-20191025-047
# destory     20191025
# material          --
# Name: Z-L19-20191025-047, dtype: object
# Z-L19-20191025-048
# destory     20191025
# material          --
# Name: Z-L19-20191025-048, dtype: object
# Z-L19-20191025-049
# deliver     20191026
# material          --
# Name: Z-L19-20191025-049, dtype: object
# Z-L19-20191025-050
# deliver     20191026
# material          --
# Name: Z-L19-20191025-050, dtype: object
# Z-L19-20191025-051
# deliver     20191026
# material          --
# Name: Z-L19-20191025-051, dtype: object
# Z-L19-20191025-052
# deliver     20191026
# material          --
# Name: Z-L19-20191025-052, dtype: object
# Z-L19-20191025-053
# deliver     20191026
# material          --
# Name: Z-L19-20191025-053, dtype: object
# Z-L19-20191025-054
# deliver     20191026
# material          --
# Name: Z-L19-20191025-054, dtype: object
# Z-L19-20191025-055
# deliver     20191026
# material          --
# Name: Z-L19-20191025-055, dtype: object
# Z-L19-20191025-056
# deliver     20191026
# material          --
# Name: Z-L19-20191025-056, dtype: object
# Z-L19-20191104-001
# create      20191104
# material          --
# Name: Z-L19-20191104-001, dtype: object
# Z-L19-20191104-002
# create      20191104
# material          --
# Name: Z-L19-20191104-002, dtype: object
# Z-L19-20191104-003
# create      20191104
# material          --
# Name: Z-L19-20191104-003, dtype: object
# Z-L19-20191104-004
# create      20191104
# material          --
# Name: Z-L19-20191104-004, dtype: object
# Z-L19-20191104-005
# create      20191104
# material          --
# Name: Z-L19-20191104-005, dtype: object
# Z-L19-20191104-006
# create      20191104
# material          --
# Name: Z-L19-20191104-006, dtype: object
# Z-L19-20191104-007
# create      20191104
# material          --
# Name: Z-L19-20191104-007, dtype: object
# Z-L19-20191104-001
# deliver     20191104
# material          --
# Name: Z-L19-20191104-001, dtype: object
# Z-L19-20191104-002
# deliver     20191104
# material          --
# Name: Z-L19-20191104-002, dtype: object
# Z-L19-20191104-003
# deliver     20191104
# material          --
# Name: Z-L19-20191104-003, dtype: object
# Z-L19-20191104-004
# deliver     20191104
# material          --
# Name: Z-L19-20191104-004, dtype: object
# Z-L19-20191104-005
# deliver     20191104
# material          --
# Name: Z-L19-20191104-005, dtype: object
# Z-L19-20191104-006
# deliver     20191104
# material          --
# Name: Z-L19-20191104-006, dtype: object
# Z-L19-20191104-007
# deliver     20191104
# material          --
# Name: Z-L19-20191104-007, dtype: object
# Z-L19-20190103-001
# deliver     20190612
# material          --
# Name: Z-L19-20190103-001, dtype: object
# Z-L19-20190103-002
# deliver     20190612
# material          --
# Name: Z-L19-20190103-002, dtype: object
# Z-L19-20190103-003
# deliver     20190612
# material          --
# Name: Z-L19-20190103-003, dtype: object
# Z-L19-20191129-002
# create      20191129
# material          --
# Name: Z-L19-20191129-002, dtype: object
# Z-L19-20191129-003
# create      20191129
# material          --
# Name: Z-L19-20191129-003, dtype: object
# Z-L19-20191129-004
# create      20191129
# material          --
# Name: Z-L19-20191129-004, dtype: object
# Z-L19-20191129-005
# create      20191129
# material          --
# Name: Z-L19-20191129-005, dtype: object
# Z-L19-20191129-006
# create      20191129
# material          --
# Name: Z-L19-20191129-006, dtype: object
# Z-L19-20191129-007
# create      20191129
# material          --
# Name: Z-L19-20191129-007, dtype: object
# Z-L19-20191129-008
# create      20191129
# material          --
# Name: Z-L19-20191129-008, dtype: object
# Z-L19-20191129-009
# create      20191129
# material          --
# Name: Z-L19-20191129-009, dtype: object
# Z-L19-20191129-010
# create      20191129
# material          --
# Name: Z-L19-20191129-010, dtype: object
# Z-L19-20191129-011
# create      20191129
# material          --
# Name: Z-L19-20191129-011, dtype: object
# Z-L19-20191129-012
# create      20191129
# material          --
# Name: Z-L19-20191129-012, dtype: object
# Z-L19-20191129-013
# create      20191129
# material          --
# Name: Z-L19-20191129-013, dtype: object
# Z-L19-20191129-014
# create      20191129
# material          --
# Name: Z-L19-20191129-014, dtype: object
# Z-L19-20191129-015
# create      20191129
# material          --
# Name: Z-L19-20191129-015, dtype: object
# Z-L19-20191129-016
# create      20191129
# material          --
# Name: Z-L19-20191129-016, dtype: object
# Z-L19-20191129-017
# create      20191129
# material          --
# Name: Z-L19-20191129-017, dtype: object
# Z-L19-20191129-018
# create      20191129
# material          --
# Name: Z-L19-20191129-018, dtype: object
# Z-L19-20191129-019
# create      20191129
# material          --
# Name: Z-L19-20191129-019, dtype: object
# Z-L19-20191129-020
# create      20191129
# material          --
# Name: Z-L19-20191129-020, dtype: object
# Z-L19-20191129-021
# create      20191129
# material          --
# Name: Z-L19-20191129-021, dtype: object
# Z-L19-20191129-022
# create      20191129
# material          --
# Name: Z-L19-20191129-022, dtype: object
# Z-L19-20191129-023
# create      20191129
# material          --
# Name: Z-L19-20191129-023, dtype: object
# Z-L19-20191129-024
# create      20191129
# material          --
# Name: Z-L19-20191129-024, dtype: object
# Z-L19-20191129-025
# create      20191129
# material          --
# Name: Z-L19-20191129-025, dtype: object
# Z-L19-20191129-026
# create      20191129
# material          --
# Name: Z-L19-20191129-026, dtype: object
# Z-L19-20191129-027
# create      20191129
# material          --
# Name: Z-L19-20191129-027, dtype: object
# Z-L19-20191129-028
# create      20191129
# material          --
# Name: Z-L19-20191129-028, dtype: object
# Z-L19-20191129-029
# create      20191129
# material          --
# Name: Z-L19-20191129-029, dtype: object
# Z-L19-20191129-030
# create      20191129
# material          --
# Name: Z-L19-20191129-030, dtype: object
# Z-L19-20191129-031
# create      20191129
# material          --
# Name: Z-L19-20191129-031, dtype: object
# Z-L19-20191129-032
# create      20191129
# material          --
# Name: Z-L19-20191129-032, dtype: object
# Z-L19-20191129-018
# destory     20191129
# material          --
# Name: Z-L19-20191129-018, dtype: object
# Z-L19-20191129-019
# destory     20191129
# material          --
# Name: Z-L19-20191129-019, dtype: object
# Z-L19-20191129-020
# destory     20191129
# material          --
# Name: Z-L19-20191129-020, dtype: object
# Z-L19-20191129-021
# destory     20191129
# material          --
# Name: Z-L19-20191129-021, dtype: object
# Z-L19-20191129-022
# destory     20191129
# material          --
# Name: Z-L19-20191129-022, dtype: object
# Z-L19-20191129-023
# destory     20191129
# material          --
# Name: Z-L19-20191129-023, dtype: object
# Z-L19-20191129-024
# destory     20191129
# material          --
# Name: Z-L19-20191129-024, dtype: object
# Z-L19-20191129-025
# destory     20191129
# material          --
# Name: Z-L19-20191129-025, dtype: object
# Z-L19-20191129-026
# destory     20191129
# material          --
# Name: Z-L19-20191129-026, dtype: object
# Z-L19-20191129-027
# destory     20191129
# material          --
# Name: Z-L19-20191129-027, dtype: object
# Z-L19-20191129-028
# destory     20191129
# material          --
# Name: Z-L19-20191129-028, dtype: object
# Z-L19-20191129-029
# destory     20191129
# material          --
# Name: Z-L19-20191129-029, dtype: object
# Z-L19-20191129-030
# destory     20191129
# material          --
# Name: Z-L19-20191129-030, dtype: object
# Z-L19-20191129-031
# destory     20191129
# material          --
# Name: Z-L19-20191129-031, dtype: object
# Z-L19-20191129-032
# destory     20191129
# material          --
# Name: Z-L19-20191129-032, dtype: object
# Z-L19-20191129-002
# deliver     20191129
# material          --
# Name: Z-L19-20191129-002, dtype: object
# Z-L19-20191129-003
# deliver     20191129
# material          --
# Name: Z-L19-20191129-003, dtype: object
# Z-L19-20191129-004
# deliver     20191129
# material          --
# Name: Z-L19-20191129-004, dtype: object
# Z-L19-20191129-005
# deliver     20191129
# material          --
# Name: Z-L19-20191129-005, dtype: object
# Z-L19-20191129-006
# deliver     20191129
# material          --
# Name: Z-L19-20191129-006, dtype: object
# Z-L19-20191129-007
# deliver     20191129
# material          --
# Name: Z-L19-20191129-007, dtype: object
# Z-L19-20191129-008
# deliver     20191129
# material          --
# Name: Z-L19-20191129-008, dtype: object
# Z-L19-20191129-009
# deliver     20191129
# material          --
# Name: Z-L19-20191129-009, dtype: object
# Z-L19-20191129-010
# deliver     20191129
# material          --
# Name: Z-L19-20191129-010, dtype: object
# Z-L19-20191129-011
# deliver     20191129
# material          --
# Name: Z-L19-20191129-011, dtype: object
# Z-L19-20191129-012
# deliver     20191129
# material          --
# Name: Z-L19-20191129-012, dtype: object
# Z-L19-20191129-013
# deliver     20191129
# material          --
# Name: Z-L19-20191129-013, dtype: object
# Z-L19-20191129-014
# deliver     20191129
# material          --
# Name: Z-L19-20191129-014, dtype: object
# Z-L19-20191129-015
# deliver     20191129
# material          --
# Name: Z-L19-20191129-015, dtype: object
# Z-L19-20191129-016
# deliver     20191129
# material          --
# Name: Z-L19-20191129-016, dtype: object
# Z-L19-20191129-017
# deliver     20191129
# material          --
# Name: Z-L19-20191129-017, dtype: object
# Z-L19-20191206-002
# create      20191206
# material          --
# Name: Z-L19-20191206-002, dtype: object
# Z-L19-20191206-003
# create      20191206
# material          --
# Name: Z-L19-20191206-003, dtype: object
# Z-L19-20191206-004
# create      20191206
# material          --
# Name: Z-L19-20191206-004, dtype: object
# Z-L19-20191206-002
# deliver     20191209
# material          --
# Name: Z-L19-20191206-002, dtype: object
# Z-L19-20191206-003
# deliver     20191209
# material          --
# Name: Z-L19-20191206-003, dtype: object
# Z-L19-20191206-004
# deliver     20191209
# material          --
# Name: Z-L19-20191206-004, dtype: object
# Z-L19-20191223-001
# create      20191223
# material          --
# Name: Z-L19-20191223-001, dtype: object
# Z-L19-20191223-001
# deliver     20191223
# material          --
# Name: Z-L19-20191223-001, dtype: object
# done

# %%
ir.check()
# Out:
#                       create   deliver destory material
# Z-L19-20181229-001  20181229        --      --    paper
# Z-L19-20181229-001        --  20190612      --       --
# Pass.
#                       create   deliver destory material
# Z-L19-20181229-002  20181229        --      --    paper
# Z-L19-20181229-002        --  20190612      --       --
# Pass.
#                       create   deliver destory material
# Z-L19-20181229-003  20181229        --      --    paper
# Z-L19-20181229-003        --  20190612      --       --
# Pass.
#                       create   deliver destory material
# Z-L19-20181229-004  20181229        --      --    paper
# Z-L19-20181229-004        --  20190612      --       --
# Pass.
#                       create   deliver destory material
# Z-L19-20181229-005  20181229        --      --    paper
# Z-L19-20181229-005        --  20190612      --       --
# Pass.
#                       create   deliver destory material
# Z-L19-20181229-006  20181229        --      --    paper
# Z-L19-20181229-006        --  20190612      --       --
# Pass.
#                       create   deliver destory material
# Z-L19-20181229-007  20181229        --      --    paper
# Z-L19-20181229-007        --  20190612      --       --
# Pass.
#                       create   deliver destory material
# Z-L19-